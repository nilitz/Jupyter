# %% [markdown]
# ### Matplot
#
# #### plt.plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,2,10)
y = x**2

#on cree une figure (en premier)
plt.figure(figsize=(12,5))
#trait
plt.plot(x,y,label='quadratic')
plt.plot(x,x**3,label='cubic')
#nuage de points
plt.scatter(x,y, lw=0)
plt.title('Figure')
plt.xlabel('Axe X')
plt.ylabel('Axe Y')
plt.legend()
plt.show()
plt.savefig('matplot.png')
